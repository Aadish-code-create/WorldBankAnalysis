# %%
"""
Data Ingestion and Profiling
Objective: To diagnose the raw dataset 
Required Python Packages
- pandas
- openpyxl
- pathlib(built into Python)

Tasks performed:
- Load all datasets
- Verify successful ingestion
- Inspect schema
- Assess data quality
- Document observations

** No modification to raw data.
"""
# Out:
# '\nData Ingestion and Profiling\nObjective: To diagnose the raw dataset \nRequired Python Packages\n- pandas\n- openpyxl\n- pathlib(built into Python)\n\nTasks performed:\n- Load all datasets\n- Verify successful ingestion\n- Inspect schema\n- Assess data quality\n- Document observations\n\n** No modification to raw data.\n'

# %%
import pandas as pd
from pathlib import Path

# %%
data_path = Path("../data/raw")

World_Bank_File = data_path / "WorldBank.xlsx"
HDI_File = data_path / "HDI.csv"
Dictionary_File = data_path / "world_indicators_data_dictionary.csv"

# %%
print(World_Bank_File.exists())
print(HDI_File.exists())
print(Dictionary_File.exists())
# Out:
# True
# True
# True

# %%
world_bank = pd.read_excel(World_Bank_File)
hdi = pd.read_csv(HDI_File)
dictionary = pd.read_csv(Dictionary_File, encoding="latin1")

# %%
print("World Bank:", world_bank.shape)

print("HDI:", hdi.shape)

print("Data Dictionary:", dictionary.shape)
# Out:
# World Bank: (12449, 15)
# HDI: (206, 1008)
# Data Dictionary: (58, 3)

# %%
# Initial Dataset Inspection 
# understanding overall structure of each dataset

# %%
world_bank.head()
# Out:
#   Country Name Country Code      Region IncomeGroup  Year  \
# 0  Afghanistan          AFG  South Asia  Low income  2018
# 1  Afghanistan          AFG  South Asia  Low income  2017
# 2  Afghanistan          AFG  South Asia  Low income  2016
# 3  Afghanistan          AFG  South Asia  Low income  2015
# 4  Afghanistan          AFG  South Asia  Low income  2014
#
#    Birth rate, crude (per 1,000 people)  Death rate, crude (per 1,000 people)  \
# 0                                   NaN                                   NaN
# 1                                33.211                                 6.575
# 2                                33.981                                 6.742
# 3                                34.809                                 6.929
# 4                                35.706                                 7.141
#
#    Electric power consumption (kWh per capita)     GDP (USD)  \
# 0                                          NaN  1.936300e+10
# ...

# %%
world_bank.tail()
# Out:
#       Country Name Country Code              Region IncomeGroup  Year  \
# 12444     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1964
# 12445     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1963
# 12446     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1962
# 12447     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1961
# 12448     Zimbabwe          ZWE  Sub-Saharan Africa  Low income  1960
#
#        Birth rate, crude (per 1,000 people)  \
# 12444                                47.770
# 12445                                47.876
# 12446                                47.950
# 12447                                47.988
# 12448                                47.996
#
#        Death rate, crude (per 1,000 people)  \
# 12444                                13.083
# 12445                                13.419
# 12446                                13.762
# 12447                                14.104
# 12448                                14.441
#
# ...

# %%
hdi.head()
# Out:
#   iso3               country    hdicode region  hdi_rank_2021  hdi_1990  \
# 0  AFG           Afghanistan        Low     SA          180.0     0.273
# 1  AGO                Angola     Medium    SSA          148.0       NaN
# 2  ALB               Albania       High    ECA           67.0     0.647
# 3  AND               Andorra  Very High    NaN           40.0       NaN
# 4  ARE  United Arab Emirates  Very High     AS           26.0     0.728
#
#    hdi_1991  hdi_1992  hdi_1993  hdi_1994  ...  mf_2012  mf_2013  mf_2014  \
# 0     0.279     0.287     0.297     0.292  ...     1.86     1.88     1.66
# 1       NaN       NaN       NaN       NaN  ...     4.09     4.53     3.97
# 2     0.629     0.614     0.617     0.624  ...    12.44    11.49    13.14
# 3       NaN       NaN       NaN       NaN  ...      NaN      NaN      NaN
# 4     0.739     0.742     0.748     0.755  ...    49.56    49.68    55.49
#
#    mf_2015  mf_2016  mf_2017  mf_2018  mf_2019  mf_2020  mf_2021
# ...

# %%
hdi.tail()
# Out:
#           iso3                          country hdicode region  hdi_rank_2021  \
# 201    ZZG.ECA          Europe and Central Asia     NaN    NaN            NaN
# 202    ZZH.LAC  Latin America and the Caribbean     NaN    NaN            NaN
# 203     ZZI.SA                       South Asia     NaN    NaN            NaN
# 204    ZZJ.SSA               Sub-Saharan Africa     NaN    NaN            NaN
# 205  ZZK.WORLD                            World     NaN    NaN            NaN
#
#      hdi_1990  hdi_1991  hdi_1992  hdi_1993  hdi_1994  ...    mf_2012  \
# 201     0.664     0.661     0.654     0.652     0.647  ...  13.107171
# 202     0.633     0.638     0.643     0.648     0.654  ...  14.114108
# 203     0.442     0.447     0.453     0.457     0.462  ...   4.699407
# 204     0.407     0.410     0.410     0.411     0.413  ...   3.437760
# 205     0.601     0.604     0.607     0.610     0.614  ...  12.186601
#
#        mf_2013    mf_2014    mf_2015    mf_2016    mf_2017    mf_2018  \
# ...

# %%
dictionary.head()
# Out:
#        Table         Field                                     Description
# 0  WorldBank  Country Name                         The name of the country
# 1  WorldBank  Country Code  The three letter code representing the country
# 2  WorldBank        Region            The World Bank region of the country
# 3  WorldBank   IncomeGroup      The World Bank Income Group of the country
# 4  WorldBank          Year  The Year in which the statistics were recorded

# %%
dictionary.tail()
# Out:
#    Table                   Field  \
# 53   hdi  rankdiff_hdi_phdi_2021
# 54   hdi               phdi_xxxx
# 55   hdi      diff_hdi_phdi_xxxx
# 56   hdi           co2_prod_xxxx
# 57   hdi                 mf_xxxx
#
#                                           Description
# 53                   Difference in HDI rank from 2020
# 54  Planetary pressuresÐadjusted Human Development...
# 55         Difference from HDI value (%) in year xxxx
# 56  Carbon dioxide emissions per capita (productio...
# 57  Material footprint per capita (tonnes) in year...

# %%
# Schema Inspection
# looking for column names, data types, non-null values, and memory usage for each dataset.

# %%
world_bank.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12449 entries, 0 to 12448
# Data columns (total 15 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Country Name                                                  12449 non-null  str
#  1   Country Code                                                  12449 non-null  str
#  2   Region                                                        12449 non-null  str
#  3   IncomeGroup                                                   12449 non-null  str
#  4   Year                                                          12449 non-null  int64
#  5   Birth rate, crude (per 1,000 people)                          11440 non-null  float64
#  6   Death rate, crude (per 1,000 people)                          11416 non-null  float64
# ...

# %%
hdi.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Columns: 1008 entries, iso3 to mf_2021
# dtypes: float64(1004), str(4)
# memory usage: 1.6 MB

# %%
dictionary.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Table        58 non-null     str
#  1   Field        58 non-null     str
#  2   Description  58 non-null     str
# dtypes: str(3)
# memory usage: 5.3 KB

# %%
world_bank.dtypes
# Out:
# Country Name                                                        str
# Country Code                                                        str
# Region                                                              str
# IncomeGroup                                                         str
# Year                                                              int64
# Birth rate, crude (per 1,000 people)                            float64
# Death rate, crude (per 1,000 people)                            float64
# Electric power consumption (kWh per capita)                     float64
# GDP (USD)                                                       float64
# GDP per capita (USD)                                            float64
# Individuals using the Internet (% of population)                float64
# Infant mortality rate (per 1,000 live births)                   float64
# Life expectancy at birth (years)                                float64
# ...

# %%
hdi.dtypes
# Out:
# iso3                 str
# country              str
# hdicode              str
# region               str
# hdi_rank_2021    float64
#                   ...
# mf_2017          float64
# mf_2018          float64
# mf_2019          float64
# mf_2020          float64
# mf_2021          float64
# Length: 1008, dtype: object

# %%
dictionary.dtypes
# Out:
# Table          str
# Field          str
# Description    str
# dtype: object

# %%
hdi["country"].isna().sum()
# Out:
# np.int64(0)

# %%
world_bank.describe()
# Out:
#               Year  Birth rate, crude (per 1,000 people)  \
# count  12449.00000                          11440.000000
# mean    1989.00000                             28.643276
# std       17.03007                             13.131893
# min     1960.00000                              6.900000
# 25%     1974.00000                             16.600000
# 50%     1989.00000                             27.545500
# 75%     2004.00000                             40.881250
# max     2018.00000                             58.227000
#
#        Death rate, crude (per 1,000 people)  \
# count                          11416.000000
# mean                              10.588539
# std                                5.489382
# min                                1.127000
# 25%                                6.863750
# 50%                                9.200000
# 75%                               12.687000
# max                               54.444000
#
# ...

# %%
hdi.describe()
# Out:
#        hdi_rank_2021    hdi_1990    hdi_1991    hdi_1992    hdi_1993  \
# count     191.000000  152.000000  152.000000  152.000000  152.000000
# mean       95.811518    0.595112    0.597862    0.600493    0.604474
# std        55.307333    0.161918    0.161921    0.162193    0.163122
# min         1.000000    0.216000    0.218000    0.222000    0.227000
# 25%        48.500000    0.477750    0.477000    0.475250    0.474250
# 50%        96.000000    0.621500    0.623500    0.622000    0.624000
# 75%       143.500000    0.725500    0.727000    0.723750    0.724250
# max       191.000000    0.872000    0.873000    0.878000    0.880000
#
#          hdi_1994    hdi_1995    hdi_1996    hdi_1997    hdi_1998  ...  \
# count  152.000000  163.000000  163.000000  163.000000  163.000000  ...
# mean     0.609329    0.613908    0.619663    0.624975    0.630417  ...
# std      0.163818    0.162789    0.163461    0.164299    0.165177  ...
# ...

# %%
world_bank.describe(include="str")
# Out:
#        Country Name Country Code                 Region          IncomeGroup
# count         12449        12449                  12449                12449
# unique          211          211                      7                    5
# top     Afghanistan          AFG  Europe & Central Asia  Upper middle income
# freq             59           59                   3304                 3127

# %%
hdi.describe(include="str")
# Out:
#        iso3      country    hdicode region
# count   206          206        191    151
# unique  206          206          4      6
# top     AFG  Afghanistan  Very High    SSA
# freq      1            1         66     46

# %%
# Missing Value Analysis
# Finding which columns have missing values, how many, is missingness systematic or random, variable at risk.

# %%
world_bank.isnull().sum
# Out:
# <bound method DataFrame.sum of        Country Name  Country Code  Region  IncomeGroup   Year  \
# 0             False         False   False        False  False
# 1             False         False   False        False  False
# 2             False         False   False        False  False
# 3             False         False   False        False  False
# 4             False         False   False        False  False
# ...             ...           ...     ...          ...    ...
# 12444         False         False   False        False  False
# 12445         False         False   False        False  False
# 12446         False         False   False        False  False
# 12447         False         False   False        False  False
# 12448         False         False   False        False  False
#
#        Birth rate, crude (per 1,000 people)  \
# 0                                      True
# 1                                     False
# 2                                     False
# ...

# %%
hdi.isnull().sum()
# Out:
# iso3              0
# country           0
# hdicode          15
# region           55
# hdi_rank_2021    15
#                  ..
# mf_2017          38
# mf_2018          38
# mf_2019          38
# mf_2020          38
# mf_2021          38
# Length: 1008, dtype: int64

# %%
def missing_value_summary(df):
    summary = df.isnull().sum().to_frame(name = "Missing Values")
    summary["Missing %"] = (summary["Missing Values"] / len(df) * 100).round(2)
    return summary.sort_values("Missing %", ascending = False)

# %%
missing_value_summary(world_bank)
# Out:
#                                                     Missing Values  Missing %
# Individuals using the Internet (% of population)              7385      59.32
# Unemployment (% of total labor force) (modeled ...            7241      58.17
# Electric power consumption (kWh per capita)                   6601      53.02
# GDP per capita (USD)                                          2874      23.09
# GDP (USD)                                                     2871      23.06
# Infant mortality rate (per 1,000 live births)                 2465      19.80
# Life expectancy at birth (years)                              1273      10.23
# Death rate, crude (per 1,000 people)                          1033       8.30
# Birth rate, crude (per 1,000 people)                          1009       8.11
# Population density (people per sq. km of land a...             604       4.85
# IncomeGroup                                                      0       0.00
# ...

# %%
missing_value_summary(hdi).head(20)
# Out:
#                     Missing Values  Missing %
# gdi_1992                        87      42.23
# hdi_f_1990                      87      42.23
# hdi_f_1991                      87      42.23
# hdi_f_1992                      87      42.23
# hdi_m_1990                      87      42.23
# hdi_m_1992                      87      42.23
# gdi_1991                        87      42.23
# gdi_1990                        87      42.23
# hdi_m_1991                      87      42.23
# hdi_f_1993                      86      41.75
# gdi_1993                        86      41.75
# hdi_m_1994                      86      41.75
# hdi_f_1994                      86      41.75
# hdi_m_1993                      86      41.75
# gdi_1994                        86      41.75
# loss_2010                       82      39.81
# ihdi_2010                       82      39.81
# coef_ineq_2010                  82      39.81
# diff_hdi_phdi_1990              81      39.32
# ...

# %%
missing_value_summary(dictionary)
# Out:
#              Missing Values  Missing %
# Table                     0        0.0
# Field                     0        0.0
# Description               0        0.0

# %%
# Duplicate Analysis
# checking for duplicate values in the datasets.

# %%
world_bank.duplicated().sum()
# Out:
# np.int64(0)

# %%
hdi.duplicated().sum()
# Out:
# np.int64(0)

# %%
dictionary.duplicated().sum()
# Out:
# np.int64(0)

# %%
world_bank.duplicated(subset = ["Country Code","Year"]).sum()
# Out:
# np.int64(0)

# %%
hdi["iso3"].duplicated().sum()
# Out:
# np.int64(0)

# %%
dictionary.duplicated(subset = ["Field"]).sum()
# Out:
# np.int64(0)

# %%
world_bank["Country Name"].nunique()
# Out:
# 211

# %%
world_bank["Country Code"].nunique()
# Out:
# 211

# %%
world_bank["Year"].nunique()
# Out:
# 59

# %%
world_bank["Region"].nunique()
# Out:
# 7

# %%
world_bank["IncomeGroup"].nunique()
# Out:
# 5

# %%
hdi["country"].nunique()
# Out:
# 206

# %%
hdi["iso3"].nunique()
# Out:
# 206

# %%
hdi["region"].nunique()
# Out:
# 6

# %%
world_bank["Year"].min(), world_bank["Year"].max()
# Out:
# (np.int64(1960), np.int64(2018))

# %%
world_bank["GDP (USD)"].min(), world_bank["Population density (people per sq. km of land area)"].min()
# Out:
# (np.float64(8824450.0), np.float64(0.0986245))

# %%
world_bank["Country Code"].nunique() * world_bank["Year"].nunique()
# Out:
# 12449

# %%
len(world_bank)
# Out:
# 12449
